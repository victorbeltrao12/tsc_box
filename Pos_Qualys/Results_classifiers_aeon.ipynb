# %%
import pandas as pd
import numpy as np
import timeit
from datetime import timedelta
from aeon.benchmarking.results_loaders import get_estimator_results
from aeon.datasets.tsc_data_lists import univariate_equal_length

# %%
#Lista de classificadores
clfs = ['Arsenal', 'BOSS', 'CBOSS', 'CNN', 'CIF', 'Catch22', 'DrCIF',
        'FreshPRINCEClassifier', 'HIVECOTEV1', 'HIVECOTEV2', 'InceptionTimeClassifier', 'STC', 'TS-CHIEF',
        'ResNet', 'ProximityForest', 'RocketClassifier', 'TSFreshClassifier','WEASEL']

#todos os resultados dos classificadores
total_time = 0
start = timeit.default_timer()
all_results = get_estimator_results(clfs, univariate_equal_length)
stop = timeit.default_timer()
total_time += stop - start
real_time = str(timedelta(seconds=total_time))
#Transformando os resultados em um dataframe
results_df = pd.DataFrame(all_results)

#Salvando os resultados em um parquet
results_df.to_parquet('all_results.parquet', index=True)
print('Time runtime (seconds): ', real_time)
# Out:
# Time runtime (seconds):  0:00:31.445898

# %%
organized_results = pd.read_parquet('all_results.parquet').sort_index(ascending=True)
organized_results
# Out:
#                 Arsenal      BOSS     CBOSS       CNN       CIF   Catch22  \
# ACSF1          0.880000  0.870000  0.890000  0.330000  0.850000  0.850000
# Adiac          0.777494  0.772379  0.764706  0.365729  0.808184  0.716113
# ArrowHead      0.811429  0.834286  0.868571  0.702857  0.777143  0.725714
# BME            1.000000  0.773333  0.646667  0.993333  1.000000  0.913333
# Beef           0.800000  0.766667  0.833333  0.733333  0.866667  0.600000
# ...                 ...       ...       ...       ...       ...       ...
# Wine           0.833333  0.740741  0.703704  0.481481  0.796296  0.388889
# WordSynonyms   0.752351  0.652038  0.647335  0.573668  0.699060  0.537618
# Worms          0.727273  0.558442  0.597403  0.389610  0.688312  0.727273
# WormsTwoClass  0.805195  0.766234  0.805195  0.545455  0.779221  0.857143
# Yoga           0.908667  0.906000  0.923667  0.790667  0.865667  0.784000
#
#                   DrCIF  FreshPRINCEClassifier  HIVECOTEV1  HIVECOTEV2  \
# ACSF1          0.880000               0.890000    0.940000    0.930000
# Adiac          0.826087               0.841432    0.813299    0.810742
# ArrowHead      0.840000               0.628571    0.862857    0.874286
# BME            1.000000               1.000000    0.880000    1.000000
# Beef           0.866667               0.800000    0.866667    0.833333
# ...                 ...                    ...         ...         ...
# Wine           0.851852               0.796296    0.833333    0.870370
# WordSynonyms   0.694357               0.653605    0.699060    0.763323
# Worms          0.753247               0.818182    0.740260    0.753247
# WormsTwoClass  0.818182               0.831169    0.805195    0.818182
# Yoga           0.877000               0.914667    0.917667    0.928667
#
#                InceptionTimeClassifier       STC  TS-CHIEF    ResNet  \
# ACSF1                         0.910000  0.940000  0.840000  0.930000
# Adiac                         0.843990  0.818414  0.797954  0.813299
# ArrowHead                     0.862857  0.691429  0.805714  0.811429
# BME                           1.000000  0.820000  0.993333  1.000000
# Beef                          0.666667  0.700000  0.766667  0.766667
# ...                                ...       ...       ...       ...
# Wine                          0.629630  0.796296  0.870370  0.833333
# WordSynonyms                  0.744514  0.634796  0.794671  0.603448
# Worms                         0.805195  0.792208  0.818182  0.753247
# WormsTwoClass                 0.766234  0.805195  0.831169  0.753247
# Yoga                          0.905000  0.869000  0.854333  0.871333
#
#                ProximityForest  RocketClassifier  TSFreshClassifier    WEASEL
# ACSF1                 0.690000          0.880000           0.870000  0.930000
# Adiac                 0.741688          0.785166           0.810742  0.826087
# ArrowHead             0.874286          0.822857           0.691429  0.862857
# BME                   1.000000          1.000000           1.000000  0.960000
# Beef                  0.733333          0.800000           0.800000  0.900000
# ...                        ...               ...                ...       ...
# Wine                  0.592593          0.777778           0.500000  0.907407
# WordSynonyms          0.783699          0.752351           0.587774  0.739812
# Worms                 0.740260          0.727273           0.766234  0.688312
# WormsTwoClass         0.792208          0.805195           0.610390  0.740260
# Yoga                  0.877667          0.910000           0.914667  0.925667
#
# [112 rows x 18 columns]
